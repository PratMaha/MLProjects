# %%
import numpy as np
import matplotlib.pyplot as plt

# This is similar to the code from lecture 1
# to sample from a 2D Gaussian Distribution
mean = [0,0]
cov = [[1, 1.5], [1.5, 5]]
# Fix random seed to get consistent results
np.random.seed(1024)
X = np.random.multivariate_normal(mean, cov, 1000)
fig, ax = plt.subplots(figsize=(10, 10))
# c='r', dot color is red
# s=10.0, dot size is 10
# alpha=0.3, dot opacity is 0.3
ax.scatter(X[:,0], X[:,1], c='r', s=10.0, alpha=0.3, label="2D-Gaussian")
ax.grid()
ax.legend(loc = 0)
# Set x/y axis limits
ax.set_xlim([-10, 10])
ax.set_ylim([-10, 10])
fig.show()
# Out:
# /var/folders/c9/3q_3q36n4k9_t4gnwrhyd7s80000gn/T/ipykernel_92747/740042362.py:21: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# TODO: Report the estimate mean and covariance
# of the sampled points
sampled_mean = np.mean(X, axis=0)
sampled_covariance = np.cov(X[:,0],X[:,1])
print("Mean of X: ", sampled_mean)
print("Covariance : ", sampled_covariance)
# Out:
# Mean of X:  [0.0104783  0.06124546]
# Covariance :  [[1.03574467 1.56979754]
#  [1.56979754 5.08040865]]

# %%
# TODO: Plot the histogram for the x-coordinates of X
# and y-coordinates of X respectively.
# You can use the plt.hist() function
plt.subplot(1,2,1)
plt.hist(X[:,0])
plt.subplot(1,2,2)
plt.hist(X[:,1])
# Out:
# (array([  3.,  12.,  45., 110., 222., 279., 187., 107.,  29.,   6.]),
#  array([-8.09073464, -6.57100486, -5.05127508, -3.53154531, -2.01181553,
#         -0.49208575,  1.02764403,  2.54737381,  4.06710359,  5.58683337,
#          7.10656314]),
#  <BarContainer object of 10 artists>)

# %%
# TODO: Are the x-coordinates of X samples from
# some Gaussian distribution?
# If so, estimate the mean and variance.
# Do the same for the y-coordinates.
sampled_mean_R1 = np.mean(X[:,0])
sampled_mean_R2 = np.mean(X[:,1])
sampled_covariance = np.cov(X[:,0],X[:,1])
print("Mean of X Coordinate: ", sampled_mean_R1)
print("Mean of Y Coordinate: ", sampled_mean_R2)
print("Covariance : ", sampled_covariance)


# TODO: Generate a new 2D scatter plot of 1000 points,
# such that the x-coordinates(y-coordinates) of all the points
# are samples from a 1D Gaussian distribution 
# using the estimated mean and variance based on the x-coordinates(y-coordinates) of X.
np.random.seed(1024)
X_1 = np.random.normal(0.01047830014298006, np.sqrt(1.03574467), 1000)
X_2 = np.random.normal(0.061245463092547824, np.sqrt(5.08040865), 1000)

fig, ax = plt.subplots(figsize=(10, 10))
ax.scatter(X_1, X_2, c='r', s=10.0, alpha=0.3, label="2 1D-Gaussians")
ax.grid()
ax.legend(loc = 0)
# Set x/y axis limits
ax.set_xlim([-10, 10])
ax.set_ylim([-10, 10])
fig.show()
# Out:
# Mean of X Coordinate:  0.01047830014298006
# Mean of Y Coordinate:  0.061245463092547824
# Covariance :  [[1.03574467 1.56979754]
#  [1.56979754 5.08040865]]
# /var/folders/c9/3q_3q36n4k9_t4gnwrhyd7s80000gn/T/ipykernel_92747/2508210211.py:28: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# Back to the original X
fig, ax = plt.subplots(figsize=(10, 10))
# c='r', dot color is red
# s=10.0, dot size is 10
# alpha=0.3, dot opacity is 0.3
ax.scatter(X[:,0], X[:,1], c='r', s=10.0, alpha=0.3, label="2D-Gaussian")
ax.grid()
ax.legend(loc = 0)
ax.set_xlim([-10, 10])
ax.set_ylim([-10, 10])

# TODO: Plot a line segment with x = [-10, 10]
# and y = 3x + 1 onto the 2D-Gaussian plot.
# The np.linspace() function may be helpful.

fig.show()
# Out:
# /var/folders/c9/3q_3q36n4k9_t4gnwrhyd7s80000gn/T/ipykernel_92747/3864500534.py:16: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# TODO: Project X onto line y=3x + 1
# and plot the projected points on the 2D space.
# You need to remove this line and assign the projected points to X_proj.
X_proj = np.zeros(X.shape)
x = np.linspace(-10, 10, num=1000)
c = 1
m = 3
y = m*x + c
for i in range(1000):
    X_proj[i,0] = (X[i,0] - m*c + m*X[i,1])/(m*m + 1)
    X_proj[i,1] = (c + m*m*X[i,1] + m*X[i,0])/(m*m +1)

plt.subplot(1,2,1)
plt.xlabel('X Coordinates')
plt.ylabel('Y Coordinates')
plt.xlim([-10, 10])
plt.ylim([-10, 10])
plt.plot(x, y, 'r+', linestyle = '--', markersize=0.3, label="y = 3x + 1")

plt.subplot(1,2,2)
plt.xlabel('X Coordinates')
plt.ylabel('Y Coordinates')
plt.xlim([-10, 10])
plt.ylim([-10, 10])
plt.scatter(X_proj[:,0], X_proj[:,1], c = 'g', s = 10.0, alpha=1.0, label="Projected X Scatter Plot")

# Here we only plot 30 points to check the correctness
fig, ax = plt.subplots(figsize=(10, 10))
ax.scatter(X_proj[:30,0], X_proj[:30,1], c='b', s=10.0, alpha=1.0, label="Projected 2D-Gaussian")
ax.scatter(X[:30,0], X[:30,1], c='r', s=10.0, alpha=1.0, label="2D-Gaussian")
ax.grid()
ax.legend(loc = 0)
ax.set_xlim([-10, 10])
ax.set_ylim([-10, 10])
# You can also add the line from the previous plot for verification.
fig.show()
# Out:
# /var/folders/c9/3q_3q36n4k9_t4gnwrhyd7s80000gn/T/ipykernel_92747/4099930313.py:36: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# TODO: Draw the histogram of the x-coordinates
# of the projected points.
# Are the x-coordinates of the projected points
# samples from some Gaussian distribution?
# If so, estimate the mean and variance.

plt.hist(X_proj[:,0])
mean_X_proj = np.mean(X_proj[:,0])
cov_X_proj = np.cov(X_proj[:,0], X_proj[:,1])
print("Mean of X Coordinate : ", mean_X_proj)
print("Variance of X Coordinate : ", cov_X_proj[0,0])
# Out:
# Mean of X Coordinate :  -0.2805785310579377
# Variance of X Coordinate :  0.5617820770985318
